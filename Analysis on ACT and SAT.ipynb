# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# Define the problem you are finding answers for from the data given.

# %% [markdown]
# As a postgraduate who is interested in taking either one of the test to increase the chances for a future application in my further studies(Masters), I would like to find out if one test is easier than the other.

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %matplotlib inline

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Read act_2017.csv file
act_2017 = pd.read_csv('../data/act_2017.csv')

# %%
#Read sat_2017.csv file
sat_2017 = pd.read_csv('../data/sat_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %% [markdown]
# ## ACT 2017

# %%
#print the first 10 rows for act_2017
act_2017.head(10)
#item 0 is not a state of the US
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
act_2017.shape
# additional row is found in the data set of act_2017
# Out:
# (52, 7)

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 2.9+ KB

# %%
act_2017.describe()
# min for science score looks questionable as it is too low
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
act_2017.tail()
#Composite number has a 20.2x
# Out:
#             State Participation  English  Math  Reading  Science Composite
# 47       Virginia           29%     23.5  23.3     24.6     23.5      23.8
# 48     Washington           29%     20.9  21.9     22.1     22.0      21.9
# 49  West Virginia           69%     20.0  19.4     21.2     20.5      20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9      20.5
# 51        Wyoming          100%     19.4  19.8     20.8     20.6     20.2x

# %% [markdown]
# ## SAT 2017

# %%
#print the first 10 rows for sat_2017
sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
sat_2017.shape
# Out:
# (51, 5)

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat_2017.describe()
#minimum score for the Math section can never be 52 as the minimum score is 200.
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
sat_2017.tail()
# Out:
#             State Participation  Evidence-Based Reading and Writing  Math  \
# 46       Virginia           65%                                 561   541
# 47     Washington           64%                                 541   534
# 48  West Virginia           14%                                 558   528
# 49      Wisconsin            3%                                 642   649
# 50        Wyoming            3%                                 626   604
#
#     Total
# 46   1102
# 47   1075
# 48   1086
# 49   1291
# 50   1230

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer: The data shows the participation rate and individual component score of the ACT and SAT test. The state should be the link to providing a basis of comparison. There are several data entry errors which have been identifed and commented on. The there are several similar components on a difference scale such as the "Science" column in act_2017.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: The data needs to be cleaned

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:
#
# 1) There is an entry in the sat_2017 where the minimum score for the Math section is 52. However,the minimum score for a section in the SAT is 200 and the maximum is 800.
#
# 2) The act_2017 data consists of an entry "National", which is the national average of all the state.
#
# 3) There is a duplicate entry in the act_2018 data, "Maine" with an index number of 20.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %% [markdown]
# ## ACT 2017 - Data Cleaning

# %%
# remove "National" from act_2017
act_2017.drop(index=0,axis=0,inplace=True)

# %%
# found that the science score for Maryland is incorrect.
act_2017.query('Science==2.3')
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2      2.3      23.6

# %%
# amending science score for Maryland from 2.3 to 23.2
act_2017['Science'].replace(2.3,23.2,inplace = True)

# %%
# checking for other abnormalities
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  51.000000  51.000000  51.000000  51.000000
# mean   20.931373  21.182353  22.013725  21.450980
# std     2.353677   1.981989   2.067271   1.739353
# min    16.300000  18.000000  18.100000  18.200000
# 25%    19.000000  19.400000  20.450000  19.950000
# 50%    20.700000  20.900000  21.800000  21.300000
# 75%    23.300000  23.100000  24.150000  23.200000
# max    25.500000  25.300000  26.000000  24.900000

# %%
act_2017.shape
# Out:
# (51, 7)

# %% [markdown]
# ## SAT 2017 - Data Cleaning

# %%
# filter for the score with less than 200 for SAT using pandas filtering techniques
sat_2017[sat_2017['Math'] < 200]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %%
# replace the Math value of Maryland to 524
sat_2017['Math'].replace(52,524,inplace = True)

# %%
# check
sat_2017.loc[20]
# Out:
# State                                 Maryland
# Participation                              69%
# Evidence-Based Reading and Writing         536
# Math                                       524
# Total                                     1060
# Name: 20, dtype: object

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
# participation and composite should be float
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %%
# participation should be float
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
#
# 1)"Participation" in both data set should be a "float" instead of "object".
#
# 2)"Composite" in act_2017 data set should be a "float" instead of "object".

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
# define function to remove %
def clean_replace(n):
    return n.replace('%','')

# %%
# convert act_2017, Participation to float using apply function
act_2017.Participation = act_2017.Participation.apply(clean_replace).astype(float)

# %%
# convert sat_2017, Participation to float using apply function
sat_2017.Participation = sat_2017.Participation.apply(clean_replace).astype(float)

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
# composite should be float in act_2017
# checking for abnormalities
act_2017.Composite.unique()
# Out:
# array(['19.2', '19.8', '19.7', '19.4', '22.8', '20.8', '25.2', '24.1',
#        '24.2', '21.4', '19.0', '22.3', '22.6', '21.9', '21.7', '20.0',
#        '19.5', '24.3', '23.6', '25.4', '21.5', '18.6', '20.4', '20.3',
#        '17.8', '25.5', '23.9', '19.1', '22.0', '21.8', '23.7', '24.0',
#        '18.7', '20.7', '23.8', '20.5', '20.2x'], dtype=object)

# %%
# remove x from index 51 and convert column to float
act_2017.Composite = act_2017.Composite.str.replace('x','').astype(float)

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
# converting all states into lower case for all 2 dataframes
act_2017['State'] = act_2017['State'].map(lambda x: x.lower())

sat_2017['State'] = sat_2017['State'].map(lambda x: x.lower())

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
# display data types for act_2017
act_2017.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
# display data types for sat_2017
sat_2017.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#renaming columns for act_2017
act_2017.columns = ['state','act_2017_participation','act_2017_english','act_2017_math','act_2017_reading','act_2017_science','act_2017_composite']

# %%
#renaming columns for sat_2017
sat_2017.columns = ['state', 'sat_2017_participation', 'sat_2017_ebrw', 'sat_2017_math','sat_2017_total']

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# | Feature | Type | Dataset | Description |
# | --- | --- | --- | --- |
# | state | obj | act_2017 / sat_2018 | Name of the state in US |
# | act_2017_participation | float | act_2017 | The mean participation rate for each state for ACT 2017 |
# | act_2017_english | float | act_2017 | The mean english score for ACT 2017 |
# | act_2017_math | float | act_2017 | The mean math score for ACT 2017 |
# | act_2017_reading | float | act_2017 | The mean reading score for ACT 2017 |
# | act_2017_science | float | act_2017 | The mean science score for ACT 2017 |
# | act_2017_composite | float | act_2017 | The mean composite score for ACT 2017 |
# | sat_2017_participation | float | sat_2017 | The mean participation rate for each state for SAT 2017 |
# | sat_2017_ebrw | int | sat_2017 | The mean Evidence-based Reading and Writing score for each state in 2017 |
# | sat_2017_math | int | sat_2017 | The mean math score for SAT 2017 |
# |sat_2017_total | int | sat_2017 | The mean total score for SAT 2017 |

# %%
sat_2017.head()
# Out:
#         state  sat_2017_participation  sat_2017_ebrw  sat_2017_math  \
# 0     alabama                     5.0            593            572
# 1      alaska                    38.0            547            533
# 2     arizona                    30.0            563            553
# 3    arkansas                     3.0            614            594
# 4  california                    53.0            531            524
#
#    sat_2017_total
# 0            1165
# 1            1080
# 2            1116
# 3            1208
# 4            1055

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
# checking for unnecessary rows
act_2017.shape[0]
# unnecessary rows have been dropped for act_2017
# Out:
# 51

# %%
# checking for unnecessary rows
sat_2017.shape[0]
# unnecessary rows have been dropped for sat_2017
# Out:
# 51

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
# merging 2017 ACT and SAT data
act_sat_2017 = pd.merge(act_2017,sat_2017, on='state',how='outer')
act_sat_2017.head(10)
# Out:
#                   state  act_2017_participation  act_2017_english  \
# 0               alabama                   100.0              18.9
# 1                alaska                    65.0              18.7
# 2               arizona                    62.0              18.6
# 3              arkansas                   100.0              18.9
# 4            california                    31.0              22.5
# 5              colorado                   100.0              20.1
# 6           connecticut                    31.0              25.5
# 7              delaware                    18.0              24.1
# 8  district of columbia                    32.0              24.4
# 9               florida                    73.0              19.0
#
#    act_2017_math  act_2017_reading  act_2017_science  act_2017_composite  \
# 0           18.4              19.7              19.4                19.2
# 1           19.8              20.4              19.9                19.8
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
act_sat_2017.to_csv('../data/combined_2017.csv',index=False)

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %% [markdown]
# # Import 2018 Data

# %%
# Read act_2018.csv file
act_2018 = pd.read_csv('../data/act_2018_updated.csv')

# %%
# Read sat_2018.csv file
sat_2018 = pd.read_csv('../data/sat_2018.csv')

# %% [markdown]
# ## ACT 2018 - Data Exploration

# %%
# print the first 5 rows for act_2018 for a brief look at the data
act_2018.head()
# Out:
#         State  Percentage of Students Tested  Average Composite Score  \
# 0     Alabama                            100                     19.1
# 1      Alaska                             33                     20.8
# 2     Arizona                             66                     19.2
# 3    Arkansas                            100                     19.4
# 4  California                             27                     22.7
#
#    Average English Score  Average Math Score  Average Reading Score  \
# 0                   18.9                18.3                   19.6
# 1                   19.8                20.6                   21.6
# 2                   18.2                19.4                   19.5
# 3                   19.1                18.9                   19.7
# 4                   22.5                22.5                   23.0
#
#    Average Science Score
# 0                   19.0
# 1                   20.7
# 2                   19.2
# 3                   19.4
# ...

# %%
act_2018.shape
# no unnecessary row is found in the dataframe
# Out:
# (51, 7)

# %%
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
# State                            51 non-null object
# Percentage of Students Tested    51 non-null int64
# Average Composite Score          51 non-null float64
# Average English Score            51 non-null float64
# Average Math Score               51 non-null float64
# Average Reading Score            51 non-null float64
# Average Science Score            51 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 2.9+ KB

# %%
act_2018.describe()
# Out:
#        Percentage of Students Tested  Average Composite Score  \
# count                      51.000000                51.000000
# mean                       61.647059                21.486275
# std                        34.080976                 2.106278
# min                         7.000000                17.700000
# 25%                        28.500000                19.950000
# 50%                        66.000000                21.300000
# 75%                       100.000000                23.550000
# max                       100.000000                25.600000
#
#        Average English Score  Average Math Score  Average Reading Score  \
# count              51.000000           51.000000              51.000000
# mean               20.988235           21.125490              22.015686
# std                 2.446356            2.035765               2.167245
# min                16.600000           17.800000              18.000000
# ...

# %%
act_2018.tail()
# Out:
#             State  Percentage of Students Tested  Average Composite Score  \
# 46       Virginia                             24                     23.9
# 47     Washington                             24                     22.2
# 48  West Virginia                             65                     20.3
# 49      Wisconsin                            100                     20.5
# 50        Wyoming                            100                     20.0
#
#     Average English Score  Average Math Score  Average Reading Score  \
# 46                   23.8                23.3                   24.7
# 47                   21.4                22.2                   22.7
# 48                   19.8                19.4                   21.3
# 49                   19.8                20.3                   20.6
# 50                   19.0                19.7                   20.6
#
#     Average Science Score
# 46                   23.5
# 47                   22.0
# ...

# %% [markdown]
# ## ACT 2018 - Data Cleaning

# %%
# checking for data types of each column
act_2018.dtypes
# Out:
# State                             object
# Percentage of Students Tested      int64
# Average Composite Score          float64
# Average English Score            float64
# Average Math Score               float64
# Average Reading Score            float64
# Average Science Score            float64
# dtype: object

# %%
# changing the data type of 'Percentage of Students Tested' to float
act_2018['Percentage of Students Tested'] = act_2018['Percentage of Students Tested'].astype(float)

# %%
# checking data types to confirm that the changes have been made.
act_2018.dtypes
# Out:
# State                             object
# Percentage of Students Tested    float64
# Average Composite Score          float64
# Average English Score            float64
# Average Math Score               float64
# Average Reading Score            float64
# Average Science Score            float64
# dtype: object

# %%
# converting all state names into lower case
act_2018['State'] = act_2018['State'].map(lambda x: x.lower())

# %%
# renaming columns
act_2018.columns = ['state','act_2018_participation','act_2018_composite','act_2018_english','act_2018_math','act_2018_reading','act_2018_science']

# %%
# checking the column names
act_2018.columns
# Out:
# Index(['state', 'act_2018_participation', 'act_2018_composite',
#        'act_2018_english', 'act_2018_math', 'act_2018_reading',
#        'act_2018_science'],
#       dtype='object')

# %% [markdown]
# ## SAT 2018 - Data Exploration

# %%
# print the first 5 rows for sat_2018 for a brief look at the data
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
sat_2018.shape
# no unnecessary row is found in the dataframe
# Out:
# (51, 5)

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat_2018.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
sat_2018.tail()
# Out:
#             State Participation  Evidence-Based Reading and Writing  Math  \
# 46       Virginia           68%                                 567   550
# 47     Washington           69%                                 543   538
# 48  West Virginia           28%                                 513   486
# 49      Wisconsin            3%                                 641   653
# 50        Wyoming            3%                                 633   625
#
#     Total
# 46   1117
# 47   1081
# 48    999
# 49   1294
# 50   1257

# %% [markdown]
# ## SAT 2018 - Data Cleaning

# %%
# check the data types of each column
sat_2018.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
# change the data type of participation to float
sat_2018['Participation'] = sat_2018['Participation'].str.replace('%','').astype(float)

# %%
# confirm if the changes are inplace
sat_2018.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
# converting all state names into lower case
sat_2018['State'] = sat_2018['State'].map(lambda x: x.lower())

# %%
# check for unnecessary rows and columns
sat_2018.shape
# Out:
# (51, 5)

# %%
#renaming columns
sat_2018.columns = ['state', 'sat_2018_participation', 'sat_2018_ebrw', 'sat_2018_math', 'sat_2018_total']

# %%
# checking the column names
sat_2018.columns
# Out:
# Index(['state', 'sat_2018_participation', 'sat_2018_ebrw', 'sat_2018_math',
#        'sat_2018_total'],
#       dtype='object')

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
# merge 2017 combined data set to act_2018
act_sat_final = pd.merge(act_sat_2017,act_2018,on='state',how='outer')
# merge 2017 combined data with act_2018 to sat_2018
act_sat_final = pd.merge(act_sat_final,sat_2018,on='state',how='outer')

# %%
act_sat_final.head()
# Out:
#         state  act_2017_participation  act_2017_english  act_2017_math  \
# 0     alabama                   100.0              18.9           18.4
# 1      alaska                    65.0              18.7           19.8
# 2     arizona                    62.0              18.6           19.8
# 3    arkansas                   100.0              18.9           19.0
# 4  california                    31.0              22.5           22.7
#
#    act_2017_reading  act_2017_science  act_2017_composite  \
# 0              19.7              19.4                19.2
# 1              20.4              19.9                19.8
# 2              20.1              19.8                19.7
# 3              19.7              19.5                19.4
# 4              23.1              22.2                22.8
#
#    sat_2017_participation  sat_2017_ebrw  sat_2017_math  ...  \
# 0                     5.0            593            572  ...
# 1                    38.0            547            533  ...
# ...

# %%
# save the final data set as final.csv
act_sat_final.to_csv('../data/final.csv',index=False)

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
# transpose the describe function
act_sat_final.describe().T
# Out:
#                         count         mean        std    min      25%     50%  \
# act_2017_participation   51.0    65.254902  32.140842    8.0    31.00    69.0
# act_2017_english         51.0    20.931373   2.353677   16.3    19.00    20.7
# act_2017_math            51.0    21.182353   1.981989   18.0    19.40    20.9
# act_2017_reading         51.0    22.013725   2.067271   18.1    20.45    21.8
# act_2017_science         51.0    21.450980   1.739353   18.2    19.95    21.3
# act_2017_composite       51.0    21.519608   2.020695   17.8    19.80    21.4
# sat_2017_participation   51.0    39.803922  35.276632    2.0     4.00    38.0
# sat_2017_ebrw            51.0   569.117647  45.666901  482.0   533.50   559.0
# sat_2017_math            51.0   556.882353  47.121395  468.0   523.50   548.0
# sat_2017_total           51.0  1126.098039  92.494812  950.0  1055.50  1107.0
# act_2018_participation   51.0    61.647059  34.080976    7.0    28.50    66.0
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
# formula to calculate standard deviation
def StdDev(df, col):
    sum_value = 0
    for x in df[col]:
        sum_value += ((x - df[col].sum()/len(df[col]))**2)
    return((sum_value/(len(df[col])))**0.5)

# %%
# test to see if the forumla works
StdDev(act_sat_final,'sat_2018_ebrw')
# Out:
# 47.03460978357609

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
# calculate standard deviation for the data fram using dict comprehension 
{k: StdDev(act_sat_final,k) for k in act_sat_final.iloc[:,1:]}
# Out:
# {'act_2017_participation': 31.824175751231806,
#  'act_2017_english': 2.3304876369363363,
#  'act_2017_math': 1.9624620273436781,
#  'act_2017_reading': 2.0469029314842646,
#  'act_2017_science': 1.7222161451443676,
#  'act_2017_composite': 2.000786081581989,
#  'sat_2017_participation': 34.92907076664508,
#  'sat_2017_ebrw': 45.21697020437866,
#  'sat_2017_math': 46.65713364485503,
#  'sat_2017_total': 91.58351056778743,
#  'act_2018_participation': 33.745194881997506,
#  'act_2018_composite': 2.0855261815801147,
#  'act_2018_english': 2.4222536143202795,
#  'act_2018_math': 2.0157072555557174,
#  'act_2018_reading': 2.145891884510421,
#  'act_2018_science': 1.851688548483354,
#  'sat_2018_participation': 36.946619223539415,
#  'sat_2018_ebrw': 47.03460978357609,
#  'sat_2018_math': 47.30194550378352,
#  'sat_2018_total': 93.22742384464433}

# %%
# calculating standard deviation using the numpy's std method
np.std(act_sat_final)
# Out:
# act_2017_participation    31.824176
# act_2017_english           2.330488
# act_2017_math              1.962462
# act_2017_reading           2.046903
# act_2017_science           1.722216
# act_2017_composite         2.000786
# sat_2017_participation    34.929071
# sat_2017_ebrw             45.216970
# sat_2017_math             46.657134
# sat_2017_total            91.583511
# act_2018_participation    33.745195
# act_2018_composite         2.085526
# act_2018_english           2.422254
# act_2018_math              2.015707
# act_2018_reading           2.145892
# act_2018_science           1.851689
# sat_2018_participation    36.946619
# sat_2018_ebrw             47.034610
# sat_2018_math             47.301946
# sat_2018_total            93.227424
# dtype: float64

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer:
#
# My manually calculated standard deviation function and numpy's std method have the same output while the pandas describe method has a different output

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### ACT 2017 - Highest participation rates by States

# %%
# sorting for the highest participation rates by states for ACT 2017
act_sat_final[['state','act_2017_participation']].sort_values(by='act_2017_participation',ascending=False).head(18)
# Out:
#              state  act_2017_participation
# 0          alabama                   100.0
# 17        kentucky                   100.0
# 49       wisconsin                   100.0
# 44            utah                   100.0
# 42       tennessee                   100.0
# 40  south carolina                   100.0
# 36        oklahoma                   100.0
# 33  north carolina                   100.0
# 28          nevada                   100.0
# 26         montana                   100.0
# 24     mississippi                   100.0
# 23       minnesota                   100.0
# 18       louisiana                   100.0
# 25        missouri                   100.0
# 50         wyoming                   100.0
# 5         colorado                   100.0
# 3         arkansas                   100.0
# 34    north dakota                    98.0

# %% [markdown]
# Answer: As 100% is the highest that the rate could go, there are many states with the same participation rates. There are 17 states with a 100% participation rate for ACT in 2017.

# %% [markdown]
# ### ACT 2018 - Highest participation rates by States

# %%
# sorting for the highest participation rates by states for ACT 2018
act_sat_final[['state','act_2018_participation']].sort_values(by='act_2018_participation',ascending=False).head(18)
# Out:
#              state  act_2018_participation
# 0          alabama                   100.0
# 17        kentucky                   100.0
# 49       wisconsin                   100.0
# 44            utah                   100.0
# 42       tennessee                   100.0
# 40  south carolina                   100.0
# 36        oklahoma                   100.0
# 35            ohio                   100.0
# 33  north carolina                   100.0
# 28          nevada                   100.0
# 27        nebraska                   100.0
# 26         montana                   100.0
# 24     mississippi                   100.0
# 18       louisiana                   100.0
# 25        missouri                   100.0
# 50         wyoming                   100.0
# 3         arkansas                   100.0
# 23       minnesota                    99.0

# %% [markdown]
# Answer: There are 17 states with 100% participation rate for ACT in 2018.

# %% [markdown]
# ### SAT 2017 - Highest participation rates by States

# %%
# sorting for the highest participation rates by states for SAT 2017
act_sat_final[['state','sat_2017_participation']].sort_values(by='sat_2017_participation',ascending=False).head()
# Out:
#                    state  sat_2017_participation
# 8   district of columbia                   100.0
# 22              michigan                   100.0
# 6            connecticut                   100.0
# 7               delaware                   100.0
# 29         new hampshire                    96.0

# %% [markdown]
# Answer: There are 4 states with 100% participation rates for SAT in 2017.

# %% [markdown]
# ### SAT 2018 - Highest participation rates by States

# %%
# sorting for the highest participation rates by states for SAT 2018
act_sat_final[['state','sat_2018_participation']].sort_values(by='sat_2018_participation',ascending=False).head(6)
# Out:
#           state  sat_2018_participation
# 5      colorado                   100.0
# 6   connecticut                   100.0
# 7      delaware                   100.0
# 22     michigan                   100.0
# 12        idaho                   100.0
# 19        maine                    99.0

# %% [markdown]
# Answer: There are 5 states with 100% participation rates for SAT in 2018.

# %% [markdown]
# ### ACT 2017 - Lowest participation rates by States

# %%
#sorting for the lowest participation rates by states for ACT 2017
act_sat_final[['state','act_2017_participation']].sort_values(by='act_2017_participation',ascending=True).head()
# Out:
#             state  act_2017_participation
# 19          maine                     8.0
# 29  new hampshire                    18.0
# 7        delaware                    18.0
# 39   rhode island                    21.0
# 38   pennsylvania                    23.0

# %% [markdown]
# Answer: Maine has the lowest participation rates for ACT in 2017.

# %% [markdown]
# ### ACT 2018 - Lowest participation rates by States

# %%
#sorting for the lowest participation rates by states for ACT 2018
act_sat_final[['state','act_2018_participation']].sort_values(by='act_2018_participation',ascending=True).head()
# Out:
#             state  act_2018_participation
# 19          maine                     7.0
# 39   rhode island                    15.0
# 29  new hampshire                    16.0
# 7        delaware                    17.0
# 38   pennsylvania                    20.0

# %% [markdown]
# Answer: Maine has the lowest participation rates for ACT in 2018.

# %% [markdown]
# ### SAT 2017 - Lowest participation rates by States

# %%
#sorting for the lowest participation rates by states for SAT 2017
act_sat_final[['state','sat_2017_participation']].sort_values(by='sat_2017_participation',ascending=True).head()
# Out:
#            state  sat_2017_participation
# 34  north dakota                     2.0
# 24   mississippi                     2.0
# 15          iowa                     2.0
# 25      missouri                     3.0
# 44          utah                     3.0

# %% [markdown]
# Answer: There are 3 states with the lowest participation rates for SAT in 2017.

# %% [markdown]
# ### SAT 2018 - Lowest participation rates by States

# %%
#sorting for the lowest participation rates by states for SAT 2018
act_sat_final[['state','sat_2018_participation']].sort_values(by='sat_2018_participation',ascending=True).head()
# Out:
#            state  sat_2018_participation
# 34  north dakota                     2.0
# 50       wyoming                     3.0
# 41  south dakota                     3.0
# 27      nebraska                     3.0
# 49     wisconsin                     3.0

# %% [markdown]
# Answer: North Dakota has the lowest participation rates for SAT in 2018.

# %% [markdown]
# ### ACT 2017 - Highest mean composite score by States

# %%
# sorting for the highest mean composite score by state
act_sat_final[['state','act_2017_composite']].sort_values(by='act_2017_composite',ascending=False).head()
# Out:
#                    state  act_2017_composite
# 29         new hampshire                25.5
# 21         massachusetts                25.4
# 6            connecticut                25.2
# 19                 maine                24.3
# 8   district of columbia                24.2

# %% [markdown]
# Answer: New Hampshire has the highest mean composite score for ACT in 2017 with Massachusetts close behind.

# %% [markdown]
# ### ACT 2017 - Lowest mean composite score by States

# %%
# sorting for the lowest mean composite score by state
act_sat_final[['state','act_2017_composite']].sort_values(by='act_2017_composite',ascending=True).head()
# Out:
#              state  act_2017_composite
# 28          nevada                17.8
# 24     mississippi                18.6
# 40  south carolina                18.7
# 11          hawaii                19.0
# 33  north carolina                19.1

# %% [markdown]
# Answer: Nevada has the lowest mean composite score for ACT in 2017.

# %% [markdown]
# ### ACT 2018 - Highest mean composite score by States

# %%
# sorting for the highest mean composite score by state
act_sat_final[['state','act_2018_composite']].sort_values(by='act_2018_composite',ascending=False).head()
# Out:
#             state  act_2018_composite
# 6     connecticut                25.6
# 21  massachusetts                25.5
# 29  new hampshire                25.1
# 32       new york                24.5
# 22       michigan                24.4

# %% [markdown]
# Answer: Connecticut has the highest mean composite score for ACT in 2017 with Massachusetts close behind.

# %% [markdown]
# ### ACT 2018 - Lowest mean composite score by States

# %%
# sorting for the lowest mean composite score by state
act_sat_final[['state','act_2018_composite']].sort_values(by='act_2018_composite',ascending=True).head()
# Out:
#              state  act_2018_composite
# 28          nevada                17.7
# 40  south carolina                18.3
# 24     mississippi                18.6
# 11          hawaii                18.9
# 0          alabama                19.1

# %% [markdown]
# Answer: Nevada has the lowest mean composite score for ACT in 2018.

# %% [markdown]
# ### SAT 2017 - Highest mean total score by States

# %%
# sorting for the highest mean total score by states for SAT 2017
act_sat_final[['state','sat_2017_total']].sort_values(by='sat_2017_total',ascending=False).head()
# Out:
#         state  sat_2017_total
# 23  minnesota            1295
# 49  wisconsin            1291
# 15       iowa            1275
# 25   missouri            1271
# 16     kansas            1260

# %% [markdown]
# Answer: Minnesota has the highest mean total score for SAT in 2017.

# %% [markdown]
# ### SAT 2017 - Lowest mean total score by States

# %%
# sorting for the lowest mean total score by states for SAT 2017
act_sat_final[['state','sat_2017_total']].sort_values(by='sat_2017_total',ascending=True).head()
# Out:
#                    state  sat_2017_total
# 8   district of columbia             950
# 7               delaware             996
# 12                 idaho            1005
# 22              michigan            1005
# 19                 maine            1012

# %% [markdown]
# Answer: District of Columbia has the lowest mean total score for SAT in 2017.

# %% [markdown]
# ### SAT 2018 - Highest mean total score by States

# %%
# sorting for the highest mean total score by states for SAT 2018
act_sat_final[['state','sat_2018_total']].sort_values(by='sat_2018_total',ascending=False).head()
# Out:
#            state  sat_2018_total
# 23     minnesota            1298
# 49     wisconsin            1294
# 34  north dakota            1283
# 15          iowa            1265
# 16        kansas            1265

# %% [markdown]
# Answer: Minnesota has the highest mean total score for SAT in 2018.

# %% [markdown]
# ### SAT 2018 - Lowest mean total score by States

# %%
# sorting for the lowest mean total score by states for SAT 2018
act_sat_final[['state','sat_2018_total']].sort_values(by='sat_2018_total',ascending=True).head()
# Out:
#                    state  sat_2018_total
# 8   district of columbia             977
# 7               delaware             998
# 48         west virginia             999
# 12                 idaho            1001
# 44                  utah            1010

# %% [markdown]
# Answer: District of Columbia has the lowest mean total score for SAT in 2018.

# %% [markdown]
# ### Do any states with 100% participation on a given test have a rate change year-to-year?

# %% [markdown]
# #### ACT

# %%
# filter for 100% participation in 2017 and <100% participation in 2018
# OR
# filter for <100% participation in 2017 and 100% participation in 2018#
act_sat_final.loc[((act_sat_final['act_2017_participation']==100) & (act_sat_final['act_2018_participation']!=100)) | ((act_sat_final['act_2017_participation']!=100) & (act_sat_final['act_2018_participation']==100))][['state','act_2017_participation','act_2018_participation','sat_2017_participation','sat_2018_participation']]
# Out:
#         state  act_2017_participation  act_2018_participation  \
# 5    colorado                   100.0                    30.0
# 23  minnesota                   100.0                    99.0
# 27   nebraska                    84.0                   100.0
# 35       ohio                    75.0                   100.0
#
#     sat_2017_participation  sat_2018_participation
# 5                     11.0                   100.0
# 23                     3.0                     4.0
# 27                     3.0                     3.0
# 35                    12.0                    18.0

# %% [markdown]
# Answer: Colorado and Minnesota dropped from a 100% participation rate while Nebraska and Ohio increased to a 100% participation rate from 2017 to 2018.

# %% [markdown]
# Comment: Colorado's participation rate dropped 70% between 2017 and 2018 drastically. However, the participation rate for SAT increased to 100% in 2018.

# %% [markdown]
# #### SAT

# %%
# filter for 100% participation in 2017 and <100% participation in 2018
# OR
# filter for <100% participation in 2017 and 100% participation in 2018
act_sat_final.loc[((act_sat_final['sat_2017_participation']==100) & (act_sat_final['sat_2018_participation']!=100)) | ((act_sat_final['sat_2017_participation']!=100) & (act_sat_final['sat_2018_participation']==100))][['state','act_2017_participation','act_2018_participation','sat_2017_participation','sat_2018_participation']]
# Out:
#                    state  act_2017_participation  act_2018_participation  \
# 5               colorado                   100.0                    30.0
# 8   district of columbia                    32.0                    32.0
# 12                 idaho                    38.0                    36.0
#
#     sat_2017_participation  sat_2018_participation
# 5                     11.0                   100.0
# 8                    100.0                    92.0
# 12                    93.0                   100.0

# %% [markdown]
# Answer: District of Columbia dropped from a 100% participation rate while Colorado and Idaho increased to a 100% participation rate from 2017 to 2018.

# %% [markdown]
# ### Do any states have >50% participation on *both* tests either year?

# %%
# filter for >50% participation for ACT and SAT in 2017
# OR
# filter for >50% participation for ACT and SAT in 2018
act_sat_final.loc[((act_sat_final['act_2017_participation']>50) & (act_sat_final['sat_2017_participation']>50)) | ((act_sat_final['act_2018_participation']>50) & (act_sat_final['sat_2018_participation']>50))][['state','act_2017_participation','act_2018_participation','sat_2017_participation','sat_2018_participation']]
# Out:
#              state  act_2017_participation  act_2018_participation  \
# 9          florida                    73.0                    66.0
# 10         georgia                    55.0                    53.0
# 11          hawaii                    90.0                    89.0
# 33  north carolina                   100.0                   100.0
# 40  south carolina                   100.0                   100.0
#
#     sat_2017_participation  sat_2018_participation
# 9                     83.0                    56.0
# 10                    61.0                    70.0
# 11                    55.0                    56.0
# 33                    49.0                    52.0
# 40                    50.0                    55.0

# %% [markdown]
# Answer: Florida, Georgia, Hawaii, North Carolina and South Carolina have more than 50% in participation rates for both ACT and SAT in either 2017 or 2018.

# %% [markdown]
# Comment: ACT in North and South Carolina seems to be mandatory. However, SAT participation rates seem to be increasing as well.

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
fig, ax = plt.subplots(figsize=(20,13))
sns.set(font_scale=1.4)
mask = np.zeros_like(act_sat_final.corr())
mask[np.triu_indices_from(mask)] = True
sns.heatmap(act_sat_final.corr(),annot=True,vmin=-1,vmax=1,mask=mask,linewidths=0.5);

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        ax[i].set_title(list_of_titles[i])
        ax[i].set_xlabel(list_of_xlabels[i])# Set titles, labels, etc here for each subplot

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# plotting using the defined function
subplot_histograms(act_sat_final,['act_2017_participation','act_2018_participation'],['ACT 2017','ACT 2018'],['Participation Rate','Participation Rate'])

# %% [markdown]
# ### Participation Rates - Histogram

# %%
# Participation rates for SAT & ACT
plt.subplots(figsize=(15,9))

plt.subplot(2,2,1)
act_sat_final['act_2017_participation'].plot(kind='hist',color='indianred');
plt.title('ACT 2017');
plt.xlabel('Participation Rate');

plt.subplot(2,2,2)
act_sat_final['act_2018_participation'].plot(kind='hist',color='indianred');
plt.title('ACT 2018');
plt.xlabel('Participation Rate');

plt.subplot(2,2,3)
act_sat_final['sat_2017_participation'].plot(kind='hist');
plt.title('SAT 2017');
plt.xlabel('Participation Rate');

plt.subplot(2,2,4)
act_sat_final['sat_2018_participation'].plot(kind='hist');
plt.title('SAT 2018');
plt.xlabel('Participation Rate');

plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# ### Math Score - Histogram

# %%
# Math scores for SAT & ACT
plt.subplots(figsize=(15,9))

plt.subplot(2,2,1)
act_sat_final['act_2017_math'].plot(kind='hist',color='indianred');
plt.title('ACT 2017');
plt.xlabel('Math Score');

plt.subplot(2,2,2)
act_sat_final['act_2018_math'].plot(kind='hist',color='indianred');
plt.title('ACT 2018');
plt.xlabel('Math Score');

plt.subplot(2,2,3)
act_sat_final['sat_2017_math'].plot(kind='hist');
plt.title('SAT 2017');
plt.xlabel('Math Score');

plt.subplot(2,2,4)
act_sat_final['sat_2018_math'].plot(kind='hist');
plt.title('SAT 2018');
plt.xlabel('Math Score');

plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# ### Reading/Verbal Score - Histogram

# %%
# Reading/verbal scores for SAT & ACT
plt.subplots(figsize=(15,9))
fig.tight_layout()
plt.subplot(2,2,1)
act_sat_final['act_2017_reading'].plot(kind='hist',color='indianred');
plt.title('ACT 2017');
plt.xlabel('Reading Score');

plt.subplot(2,2,2)
act_sat_final['act_2018_reading'].plot(kind='hist',color='indianred');
plt.title('ACT 2018');
plt.xlabel('Reading Score');

plt.subplot(2,2,3)
act_sat_final['sat_2017_ebrw'].plot(kind='hist');
plt.title('SAT 2017');
plt.xlabel('Reading Score');

plt.subplot(2,2,4)
act_sat_final['sat_2018_ebrw'].plot(kind='hist');
plt.title('SAT 2018');
plt.xlabel('Reading Score');

plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# ### English Score (ACT only) - Histogram

# %%
# English scores for ACT
plt.subplots(figsize=(15,4.5))

plt.subplot(1,2,1)
act_sat_final['act_2017_english'].plot(kind='hist',color='indianred');
plt.title('ACT 2017');
plt.xlabel('English Score');

plt.subplot(1,2,2)
act_sat_final['act_2018_english'].plot(kind='hist',color='indianred');
plt.title('ACT 2018');
plt.xlabel('English Score');

# %% [markdown]
# ### Science Score (ACT only) - Histogram

# %%
# Science scores for ACT
plt.subplots(figsize=(15,4.5))

plt.subplot(1,2,1)
act_sat_final['act_2017_science'].plot(kind='hist',color='indianred');
plt.title('ACT 2017');
plt.xlabel('Science Score');


plt.subplot(1,2,2)
act_sat_final['act_2018_science'].plot(kind='hist',color='indianred');
plt.title('ACT 2018');
plt.xlabel('Science Score');

# %% [markdown]
# ### Composite/Total Score - Histogram

# %%
# Reading/verbal scores for SAT & ACT
plt.subplots(figsize=(15,9))

plt.subplot(2,2,1)
act_sat_final['act_2017_composite'].plot(kind='hist',color='indianred');
plt.title('ACT 2017');
plt.xlabel('Composite Score');

plt.subplot(2,2,2)
act_sat_final['act_2018_composite'].plot(kind='hist',color='indianred');
plt.title('ACT 2018');
plt.xlabel('Composite Score');

plt.subplot(2,2,3)
act_sat_final['sat_2017_total'].plot(kind='hist');
plt.title('SAT 2017');
plt.xlabel('Total Score');

plt.subplot(2,2,4)
act_sat_final['sat_2018_total'].plot(kind='hist');
plt.title('SAT 2018');
plt.xlabel('Total Score');

plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %% [markdown]
# ### SAT vs. ACT math scores for 2017

# %%
# SAT vs. ACT math scores for 2017
plt.scatter(x=act_sat_final['act_2017_math'],y=act_sat_final['sat_2017_math'],marker='x',s=100)
plt.xlabel('ACT')
plt.ylabel('SAT')
plt.title('2017 Average Math Score')
# Out:
# Text(0.5, 1.0, '2017 Average Math Score')

# %% [markdown]
# ### SAT vs. ACT verbal/reading scores for 2017

# %%
# SAT vs. ACT verbal/reading scores for 2017
plt.scatter(x=act_sat_final['act_2017_reading'],y=act_sat_final['sat_2017_ebrw'],marker='>',s=80)
plt.xlabel('ACT')
plt.ylabel('SAT')
plt.title('2017 Average Reading Score')
# Out:
# Text(0.5, 1.0, '2017 Average Reading Score')

# %% [markdown]
# ### SAT vs. ACT total/composite scores for 2017

# %%
# SAT vs. ACT total/composite scores for 2017
plt.scatter(x=act_sat_final['act_2017_composite'],y=act_sat_final['sat_2017_total'],marker='P',s=80)
plt.xlabel('ACT')
plt.ylabel('SAT')
plt.title('2017 Average Composite/Total Score')
# Out:
# Text(0.5, 1.0, '2017 Average Composite/Total Score')

# %% [markdown]
# ### Total scores for SAT 2017 vs. 2018

# %%
# Total scores for SAT 2017 vs. 2018
plt.scatter(x=act_sat_final['sat_2017_total'],y=act_sat_final['sat_2018_total'],marker='^',s=80);
plt.xlabel('2017');
plt.ylabel('2018');
plt.title('SAT Average Total Score');

# %% [markdown]
# ### Composite scores for ACT 2017 vs. 2018

# %%
# Composite scores for ACT 2017 vs. 2018
plt.scatter(x=act_sat_final['act_2017_composite'],y=act_sat_final['act_2018_composite'],marker='<',s=80);
plt.xlabel('2017');
plt.ylabel('2018');
plt.title('ACT Average Composite Score');

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %% [markdown]
# ### Participation Rate - Boxplot

# %%
# SAT and ACT participation
sns.set(style='white',color_codes=True)
plt.subplots(figsize=(10,9));
sns.boxplot(data=act_sat_final[['act_2017_participation','sat_2017_participation','act_2018_participation','sat_2018_participation']],palette={'act_2017_participation':'r','sat_2017_participation':'b','act_2018_participation':'r','sat_2018_participation':'b'});
sns.swarmplot(data=act_sat_final[['act_2017_participation','sat_2017_participation','act_2018_participation','sat_2018_participation']],size=10,color='0.2');
plt.title('ACT/SAT Participation Rate',fontsize=30);

# %% [markdown]
# ### ACT Math Score - Boxplot

# %%
sns.set(style='white',color_codes=True)
plt.subplots(figsize=(10,9));
sns.boxplot(data=act_sat_final[['act_2017_math','act_2018_math']],color='r');
sns.swarmplot(data=act_sat_final[['act_2017_math','act_2018_math']],size=10,color='0.2');
plt.title('ACT Math Score');
plt.xlabel('Math Score');

# %% [markdown]
# ### SAT Math Score - Boxplot

# %%
sns.set(style='white',color_codes=True)
plt.subplots(figsize=(10,9));
sns.boxplot(data=act_sat_final[['sat_2017_math','sat_2018_math']],color='b');
sns.swarmplot(data=act_sat_final[['sat_2017_math','sat_2018_math']],size=10,color='0.2');
plt.title('SAT Math Score');
plt.xlabel('Math Score');

# %% [markdown]
# ### ACT Reading Score - Boxplot

# %%
sns.set(style='white',color_codes=True)
plt.subplots(figsize=(10,9));
sns.boxplot(data=act_sat_final[['act_2017_reading','act_2018_reading']],color='r');
sns.swarmplot(data=act_sat_final[['act_2017_reading','act_2018_reading']],size=10,color='0.2');
plt.title('ACT Reading Score');
plt.xlabel('Reading Score');

# %% [markdown]
# ### SAT Evidence-based Reading and Writing Score - Boxplot

# %%
sns.set(style='white',color_codes=True)
plt.subplots(figsize=(10,9));
sns.boxplot(data=act_sat_final[['sat_2017_ebrw','sat_2018_ebrw']],color='b');
sns.swarmplot(data=act_sat_final[['sat_2017_ebrw','sat_2018_ebrw']],size=10,color='0.2');
plt.title('SAT Evidence-based Reading and Writing Score Score');
plt.xlabel('Evidence-based Reading and Writing Score Score');

# %% [markdown]
# ### ACT English Score - Boxplot

# %%
# ACT english score
sns.set(style='white',color_codes=True)
plt.subplots(figsize=(10,9));
sns.boxplot(data=act_sat_final[['act_2017_english','act_2018_english']],color='r');
sns.swarmplot(data=act_sat_final[['act_2017_english','act_2018_english']],size=10,color='0.2');
plt.title('ACT English Score');
plt.xlabel('English Score');

# %% [markdown]
# ### ACT Science Score - Boxplot

# %%
# ACT science score
sns.set(style='white',color_codes=True)
plt.subplots(figsize=(10,9));
sns.boxplot(data=act_sat_final[['act_2017_science','act_2018_science']],color='r');
sns.swarmplot(data=act_sat_final[['act_2017_science','act_2018_science']],size=10,color='0.2');
plt.title('ACT Science Score');
plt.xlabel('Science Score');

# %% [markdown]
# ### ACT Composite Score - Boxplot

# %%
# ACT composite score
sns.set(style='white',color_codes=True)
plt.subplots(figsize=(10,9));
sns.boxplot(data=act_sat_final[['act_2017_composite','act_2018_composite']],color='r');
sns.swarmplot(data=act_sat_final[['act_2017_composite','act_2018_composite']],size=10,color='0.2');
plt.title('ACT Composite Score');
plt.xlabel('Composite Score');

# %% [markdown]
# ### SAT Total Score - Boxplot

# %%
# SAT total score
sns.set(style='white',color_codes=True)
plt.subplots(figsize=(10,9));
sns.boxplot(data=act_sat_final[['sat_2017_total','sat_2018_total']],color='b');
sns.swarmplot(data=act_sat_final[['sat_2017_total','sat_2018_total']],size=10,color='0.2');
plt.title('SAT Total Score');
plt.xlabel('Total Score');

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# ### Summarizing Distributions - Participation Rates

# %% [markdown]
# The participation rates for **ACT** are slightly **skewed to the the left(negatively skewed)** as seen in the calculation for skewness below as well as the histograms plotted above. This is in part due to 18 out of 51(35%) states which have a 100% participation rate. In addition, the mean for both years are lower than the median respectively. Hence, the participation rates for ACT are **NOT** normally distributed.
#
# The participation rates for **SAT** are **skewed to the right(positively skewed)** as seen in the calculation for skewness below as well as the histograms plotted above. The mean participation rate in 2017 is higher than the median participation rate but the mean participation rate in 2018 is lower than the median participation rate.
# Although we can see an increase in both the mean and median participation rate from 2017 to 2018, there is a relatively larger than proportion increase in the median than the mean. This causes the distribution in 2018 to shift towards a normal distribution.

# %%
# left skewed = mean<median<mode
# right skewed = mean>median>mode
act_sat_final[['act_2017_participation','act_2018_participation','sat_2017_participation','sat_2018_participation']].agg([np.mean,np.median])
# Out:
#         act_2017_participation  act_2018_participation  \
# mean                 65.254902               61.647059
# median               69.000000               66.000000
#
#         sat_2017_participation  sat_2018_participation
# mean                 39.803922               45.745098
# median               38.000000               52.000000

# %%
# SKEWNESS for Participation rates
print('Skewness for ACT 2017 Participation Rate is',stats.skew(act_sat_final['act_2017_participation']))
print('Skewness for ACT 2018 Participation Rate is',stats.skew(act_sat_final['act_2018_participation']))
print('Skewness for SAT 2017 Participation Rate is',stats.skew(act_sat_final['sat_2017_participation']))
print('Skewness for SAT 2018 Participation Rate is',stats.skew(act_sat_final['sat_2018_participation']))
# Out:
# Skewness for ACT 2017 Participation Rate is -0.19211796242279808
# Skewness for ACT 2018 Participation Rate is -0.021265664102340397
# Skewness for SAT 2017 Participation Rate is 0.33617543925343646
# Skewness for SAT 2018 Participation Rate is 0.13218842829757124

# %% [markdown]
# ### Summarizing Distributions - Math Score

# %% [markdown]
# The distribution for both ACT and SAT are **skewed to the right(positively skewed)** as seen in the histogram plotted above and skewness calculated below where all the calcuations returned a number more than 1, indicating that they are not normally distributed.
#
# The mean and median for the math score of both ACT and SAT across the years are stable with insignificant fluctuations.

# %%
# left skewed = mean<median<mode
# right skewed = mean>median>mode
act_sat_final[['act_2017_math','act_2018_math','sat_2017_math','sat_2018_math']].agg([np.mean,np.median])
# Out:
#         act_2017_math  act_2018_math  sat_2017_math  sat_2018_math
# mean        21.182353       21.12549     556.882353     556.235294
# median      20.900000       20.70000     548.000000     544.000000

# %%
# SKEWNESS for Math Score
print('Skewness for ACT 2017 Math score is',stats.skew(act_sat_final['act_2017_math']))
print('Skewness for ACT 2018 Math score is',stats.skew(act_sat_final['act_2018_math']))
print('Skewness for SAT 2017 Math score is',stats.skew(act_sat_final['sat_2017_math']))
print('Skewness for SAT 2018 Math score is',stats.skew(act_sat_final['sat_2018_math']))
# Out:
# Skewness for ACT 2017 Math score is 0.3228174361152988
# Skewness for ACT 2018 Math score is 0.2615541273504424
# Skewness for SAT 2017 Math score is 0.35421485843432615
# Skewness for SAT 2018 Math score is 0.514677775442769

# %% [markdown]
# ### Summarizing Distributions - Reading Score

# %% [markdown]
# The distribution for both ACT and SAT are slightly **skewed to the right(positively skewed)** as seen in the histogram plotted above and skewness calculated below where all the calcuations returned a number more than 1, indicating that they are not normally distributed.
#
# The mean and median reading score of the ACT are stable with insignificant fluctuations. However, there is a minor drop in the mean and median Evidence-Based Reading and Writing score of the SAT from 2017 to 2018.

# %%
# left skewed = mean<median<mode
# right skewed = mean>median>mode
act_sat_final[['act_2017_reading','act_2018_reading','sat_2017_ebrw','sat_2018_ebrw']].agg([np.mean,np.median])
# Out:
#         act_2017_reading  act_2018_reading  sat_2017_ebrw  sat_2018_ebrw
# mean           22.013725         22.015686     569.117647     563.686275
# median         21.800000         21.600000     559.000000     552.000000

# %%
# SKEWNESS for reading score
print('Skewness for ACT 2017 reading score is',stats.skew(act_sat_final['act_2017_reading']))
print('Skewness for ACT 2018 reading score is',stats.skew(act_sat_final['act_2018_reading']))
print('Skewness for SAT 2017 reading score is',stats.skew(act_sat_final['sat_2017_ebrw']))
print('Skewness for SAT 2018 reading score is',stats.skew(act_sat_final['sat_2018_ebrw']))
# Out:
# Skewness for ACT 2017 reading score is 0.2613779187300745
# Skewness for ACT 2018 reading score is 0.1953899076147242
# Skewness for SAT 2017 reading score is 0.2646065965076702
# Skewness for SAT 2018 reading score is 0.27392797109625916

# %% [markdown]
# ### Summarizing Distributions - English Score (ACT only)

# %% [markdown]
# The distribution for the english score of ACT are **skewed to the right(positively skewed)** as seen in the histogram plotted above and skewness calculated below where all the calcuations returned a number more than 1, indicating that they are not normally distributed.
#
# The mean and median of the english score are stable with insignificant fluctuations across the years.

# %%
# left skewed = mean<median<mode
# right skewed = mean>median>mode
act_sat_final[['act_2017_english','act_2018_english']].agg([np.mean,np.median])
# Out:
#         act_2017_english  act_2018_english
# mean           20.931373         20.988235
# median         20.700000         20.200000

# %%
# SKEWNESS for english score
print('Skewness for ACT 2017 english score is',stats.skew(act_sat_final['act_2017_english']))
print('Skewness for ACT 2018 english score is',stats.skew(act_sat_final['act_2018_english']))
# Out:
# Skewness for ACT 2017 english score is 0.34220217359811805
# Skewness for ACT 2018 english score is 0.3604894183850984

# %% [markdown]
# ### Summarizing Distributions - Science Score (ACT only)

# %% [markdown]
# The distribution for the science score of ACT are slightly **skewed to the right(positively skewed)** as seen in the histogram plotted above and skewness calculated below where all the calcuations returned a number more than 1, indicating that they are not normally distributed. However, from 2017 to 2018, skewness has shown a shift towards a normal distribution.
#
# The mean and median are stable with insignificant fluctuations across the years.

# %%
# left skewed = mean<median<mode
# right skewed = mean>median>mode
act_sat_final[['act_2017_science','act_2018_science']].agg([np.mean,np.median])
# Out:
#         act_2017_science  act_2018_science
# mean            21.45098         21.345098
# median          21.30000         21.100000

# %%
# SKEWNESS for Science score
print('Skewness for ACT 2017 science score is',stats.skew(act_sat_final['act_2017_science']))
print('Skewness for ACT 2018 science score is',stats.skew(act_sat_final['act_2018_science']))
# Out:
# Skewness for ACT 2017 science score is 0.21233390930923077
# Skewness for ACT 2018 science score is 0.16727084253293434

# %% [markdown]
# ### Summarizing Distributions - Composite/Total Score

# %% [markdown]
# The distribution for both the composite and total score for ACT and SAT are slightly **skewed to the right(positively skewed)** as seen in the histogram plotted above and skewness calculated below where all the calcuations returned a number more than 1, indicating that they are not normally distributed.
#
# The skewness of the ACT composite score do show a decrease over the year. In addition, the mean and median ACT composite score of the ACT are similar and stable with insignificant fluctuations which further strengthen the view that the ACT composite score is slowly shifting towards a normal distribution.
#
# On the other hand, the skewness of the SAT total score show an increase between 2017 and 2018. The mean total score is higher than the median in both years. In 2018, the gap between mean and median total score for SAT widened, showing a shift away from a normal distribution.

# %%
# left skewed = mean<median<mode
# right skewed = mean>median>mode
act_sat_final[['act_2017_composite','act_2018_composite','sat_2017_total','sat_2018_total']].agg([np.mean,np.median])
# Out:
#         act_2017_composite  act_2018_composite  sat_2017_total  sat_2018_total
# mean             21.519608           21.486275     1126.098039     1120.019608
# median           21.400000           21.300000     1107.000000     1098.000000

# %%
# SKEWNESS for composite/total score
print('Skewness for ACT 2017 composite score is',stats.skew(act_sat_final['act_2017_composite']))
print('Skewness for ACT 2018 composite score is',stats.skew(act_sat_final['act_2018_composite']))
print('Skewness for SAT 2017 total score is',stats.skew(act_sat_final['sat_2017_total']))
print('Skewness for SAT 2018 total score is',stats.skew(act_sat_final['sat_2018_total']))
# Out:
# Skewness for ACT 2017 composite score is 0.3103255637098951
# Skewness for ACT 2018 composite score is 0.273600443365584
# Skewness for SAT 2017 total score is 0.30168334986069095
# Skewness for SAT 2018 total score is 0.4525994928716571

# %% [markdown]
# ### Kurtosis - Participation Rates

# %%
# greater than +1, the distribution is too peaked, less than –1 the distribution that is too flat
# KURTOSIS
print('Kurtosis for ACT 2017 Participation Rate is',stats.kurtosis(act_sat_final['act_2017_participation']))
print('Kurtosis for ACT 2018 Participation Rate is',stats.kurtosis(act_sat_final['act_2018_participation']))
print('Kurtosis for SAT 2017 Participation Rate is',stats.kurtosis(act_sat_final['sat_2017_participation']))
print('Kurtosis for SAT 2018 Participation Rate is',stats.kurtosis(act_sat_final['sat_2018_participation']))
# Out:
# Kurtosis for ACT 2017 Participation Rate is -1.5916901032787911
# Kurtosis for ACT 2018 Participation Rate is -1.688222223446668
# Kurtosis for SAT 2017 Participation Rate is -1.3643825074544609
# Kurtosis for SAT 2018 Participation Rate is -1.5347284454121928

# %% [markdown]
# ### Kurtosis - Math Score

# %%
# KURTOSIS
print('Kurtosis for ACT 2017 Math score is',stats.kurtosis(act_sat_final['act_2017_math']))
print('Kurtosis for ACT 2018 Math score is',stats.kurtosis(act_sat_final['act_2018_math']))
print('Kurtosis for SAT 2017 Math score is',stats.kurtosis(act_sat_final['sat_2017_math']))
print('Kurtosis for SAT 2018 Math score is',stats.kurtosis(act_sat_final['sat_2018_math']))
# Out:
# Kurtosis for ACT 2017 Math score is -1.0011927796225994
# Kurtosis for ACT 2018 Math score is -1.1186567459449526
# Kurtosis for SAT 2017 Math score is -0.9529168250264535
# Kurtosis for SAT 2018 Math score is -0.7993880380369975

# %% [markdown]
# ### Kurtosis - Reading Score

# %%
# KURTOSIS
print('Kurtosis for ACT 2017 reading score is',stats.kurtosis(act_sat_final['act_2017_reading']))
print('Kurtosis for ACT 2018 reading score is',stats.kurtosis(act_sat_final['act_2018_reading']))
print('Kurtosis for SAT 2017 reading score is',stats.kurtosis(act_sat_final['sat_2017_ebrw']))
print('Kurtosis for SAT 2018 reading score is',stats.kurtosis(act_sat_final['sat_2018_ebrw']))
# Out:
# Kurtosis for ACT 2017 reading score is -1.0038016291000136
# Kurtosis for ACT 2018 reading score is -1.1249632860928789
# Kurtosis for SAT 2017 reading score is -1.2193513240314324
# Kurtosis for SAT 2018 reading score is -1.0698603350559397

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: No, we do not observed this trend. The distribution for all the variables are explained in the section "Summarizing Distributions" above.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer: **Normal distribution was not observed from the math test, reading test and participation rates.**
#
# The **participation rates** between the ACT and SAT are inversely related in that the ACT are **skewed to the left** while the SAT are **skewed to the right**. In addition, considering that the mean and median defers for each test in the 2 years. We can conclude that the participation rates are not normally distributed as in the case of a normally distributed data where mean, median and mode are equal.
#
# The distribution for **Math** are **skewed to the right** for both ACT and SAT as indicated by the histogram and skewness calculated above. In addition the mean is higher than the median, concluding that the math scores are not of a normal distribution.
#
# The distribution for the **Reading** test are **skewed to the right** for both ACT and SAT portrayed by the histogram and skewness above. As per the math score, the mean is higher than the median, indicating that it is not a normal distribution.
#
# However, we do see a shift in the participation rates of ACT and SAT, math and reading score of ACT closer towards a normal distribution(skewness=0) from 2017 to 2018.
#
# These will affect our estimates as we are unsure if given another sample, the results will yield a different result. In addition, from the kurtosis calculated above is showing a more than -1 result which is signaling a flat distribution(insufficient samples). Hence, estimates from the current data set will result in a higher risk of inaccuracy.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer: **Statistical inference should not be conducted given these data.**
#
# More samples should be collected before conducting statistical inference. As calculated above, the kurtosis of the participation rates for both tests in both years are all less than -1. This shows that the distribution is relatively flat due to a lack of samples. In addition, to be able to infer about the population, we will require more samples to apply cental limit theorem.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer: No. The test score scale differently between SAT and ACT. In addition, the test format and topics are similar but **not identical** and will result in an inaccurate comparison.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %% [markdown]
# #### **Null Hypothesis**: The participation rate in the SAT is equal for both years.

# %% [markdown]
# #### **Alternative Hypothesis**: The participation rate in the SAT is **NOT** equal for both years.

# %%
# Null Hypothesis: participation in the SAT are equal for both years
# Alternative Hypothesis: participation in the SAT are NOT equal for both years
mean_2017 = act_sat_final['sat_2017_participation'].mean()
std_2017 = act_sat_final['sat_2017_participation'].std()

mean_2018 = act_sat_final['sat_2018_participation'].mean()
std_2018 = act_sat_final['sat_2018_participation'].std()

t_stat, p_value = stats.ttest_ind_from_stats(mean_2017, std_2017,51, mean_2018, std_2018,51)
print('T-stats:',t_stat)
print('P-value:',p_value)
# Out:
# T-stats: -0.8262650776952394
# P-value: 0.4106208015719348

# %% [markdown]
# P-value, 0.4106208015719348 is > 0.05, hence, there is **insufficient evidence to reject** the null hypothesis.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# https://www.edweek.org/ew/section/multimedia/states-require-students-take-sat-or-act.html
#
# As part of statewide high school accountability, students in Colorado, North and South Carolina are mandated to take either the ACT or SAT as part of the Every Student Succeeds Act.
#
# In North and South Carolina, the ACT is a sponsored mandatory milestone that the government requires all high school students to participate as a measure widely used for college admissions decisions. As universities do not have a preference for one test over the other, in a competitive environment, students tend to take both papers and submit the test with the best score as part of their application.
#
# www.ncpublicschools.org/newsroom/news/2019-20/20190924-01
#
# https://admissions.unc.edu/apply/how-we-review-test-scores/
#
# In 2017, the Colorado Department of Education chose the SAT Suite of Assessments for state testing because of the suite's strong alignment to Colorado's academic standards. Hence the shift from a 100% participation in 2017 to a 30% participation in 2018 for the ACT.
#
# https://collegereadiness.collegeboard.org/state-partnerships/colorado

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# The **trend** observed between the 2 tests in both years from a participation rate standpoint is that there seems to be a shift in the administration of the SAT from ACT. It can be observed from the histogram where there is an increase in the participation rate of the SAT while there is a decrease in the number of states with 100% participation rate. In addition, from the skewness calculated, there is a larger movement towards a normal distribution. This means that there are now lesser states with a lower participation rates. As for the distribution of ACT, the shift towards a normal distribution means that there will be lesser states with a high participation rate.

# %%
# filter for the state with the lowest participation rate in both exams on both years
act_sat_final.loc[((act_sat_final['act_2017_participation']<50) & (act_sat_final['sat_2017_participation']<50)) & ((act_sat_final['act_2018_participation']<50) & (act_sat_final['sat_2018_participation']<50))][['state','act_2017_participation','act_2018_participation','sat_2017_participation','sat_2018_participation']]
# Out:
#      state  act_2017_participation  act_2018_participation  \
# 37  oregon                    40.0                    42.0
#
#     sat_2017_participation  sat_2018_participation
# 37                    43.0                    48.0

# %% [markdown]
# While some states with a very low participation rate in one test can mean a higher participation rate in the other, I have selected the state of Oregon where the participation rate for both tests in each given year is less than 50%.
#
# The College Board can increase participation of the ACT or SAT by making the test the final graduation test(exit exam) for the students. This will make taking the test compulsary and free for every students. In addition, it will be held on a school day.
#
# It would be good to collect the same data set for PSAT, the practice version of SAT. This will provide a comparison between this year and the year before since colleges tend to provide a PSAT 1 year before the actual SAT.

# %% [markdown]
# In conclusion, given the dataset, it is unable to tell if one test is more difficult than the other as both test scores follow the same trend and distribution
